# %%
import pandas as pd

# %%
df = pd.read_csv("Data/sentiment-analysis.csv",sep=', ')
df
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6028\3194350461.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("Data/sentiment-analysis.csv",sep=', ')
#                                                 "Text Sentiment  \
# 0                           """I love this product!""  Positive
# 1                      """The service was terrible.""  Negative
# 2                         """This movie is amazing!""  Positive
# 3   """I'm so disappointed with their customer sup...  Negative
# 4             """Just had the best meal of my life!""  Positive
# ..                                                ...       ...
# 91  """Just had the most amazing vacation! I can't...  Positive
# 92  """The food at this restaurant was awful. Neve...  Negative
# ...

# %%
df.isnull().sum()
# Out:
# "Text                0
# Sentiment            0
# Source               0
# Date/Time            0
# User ID              0
# Location             0
# Confidence Score"    0
# dtype: int64

# %%
df = df.copy()
dups = df[df.duplicated() == True]
dups
# Out:
#                                                 "Text Sentiment  \
# 75  """The hotel staff were rude and unprofessiona...  Negative
# 76  """The food at this restaurant was mediocre. N...  Negative
# 77  """This song always puts me in a nostalgic moo...  Positive
# 78  """The website loading speed is frustratingly ...  Negative
# 79                          """I love this product!""  Positive
# 80                     """The service was terrible.""  Negative
# 81                        """This movie is amazing!""  Positive
# 82  """I'm so disappointed with their customer sup...  Negative
# 83            """Just had the best meal of my life!""  Positive
# 84        """The quality of this product is subpar.""  Negative
# 85  """I can't stop listening to this song. It's i...  Positive
# 86   """Their website is so user-friendly. Love it!""  Positive
# 87          """I loved the movie! It was fantastic!""  Positive
# 88            """The customer service was terrible.""  Negative
# ...

# %%
df.loc[0]
# Out:
# "Text                """I love this product!""
# Sentiment                             Positive
# Source                                 Twitter
# Date/Time                  2023-06-15 09:23:14
# User ID                               @user123
# Location                              New York
# Confidence Score"                        0.85"
# Name: 0, dtype: object

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: ["Text, Sentiment, Source, Date/Time, User ID, Location, Confidence Score"]
# Index: []

# %%
df.nunique()
# Out:
# "Text                75
# Sentiment             2
# Source               27
# Date/Time            75
# User ID              73
# Location             11
# Confidence Score"    25
# dtype: int64

# %% [markdown]
# In the data warehouse, sentiment, source, and location should be normalized.

# %%
df.Source.unique()
# Out:
# array(['Twitter', 'Yelp Reviews', 'IMDb', 'Online Forum', 'TripAdvisor',
#        'Amazon Reviews', 'Spotify', 'Website Testimonial', 'Goodreads',
#        'Online Store', 'Zomato', 'Website Review', 'Trip Report',
#        'Event Review', 'Online Chat', 'Airline Review',
#        'Theme Park Review', 'Music Review', 'Retail Store',
#        'Online Helpdesk', 'Gaming Forum', 'Travel Website',
#        'Hotel Review', 'Food Blog', 'TV Show Review', 'Art Review',
#        'Travel Blog'], dtype=object)

# %%
df.Location.unique()
# Out:
# array(['New York', 'Los Angeles', 'London', 'Toronto', 'Paris',
#        'San Francisco', 'Berlin', 'Sydney', 'Mumbai', 'Orlando',
#        'Chicago'], dtype=object)

# %%
df.loc[:,'"Text'] = df['"Text'].str.replace(r'\"', '', regex=True)
df.loc[:,'Confidence Score"'] = df['Confidence Score"'].str.replace(r'\"', '', regex=True)
df.loc[:,'User ID'] = df['User ID'].str.replace(r'@', '', regex=True)

# %%
df.rename(columns={'"Text': 'Text', 'Confidence Score"': 'Confidence Score'}, inplace=True)

# %%
df
# Out:
#                                                  Text Sentiment  \
# 0                                I love this product!  Positive
# 1                           The service was terrible.  Negative
# 2                              This movie is amazing!  Positive
# 3    I'm so disappointed with their customer support.  Negative
# 4                  Just had the best meal of my life!  Positive
# ..                                                ...       ...
# 70  The ride on this cruise ship was an unforgetta...  Positive
# 71  The product I received was of poor quality. It...  Negative
# 72  This book kept me hooked from start to finish....  Positive
# 73  The customer service at this store is outstand...  Positive
# 74  I had a frustrating experience with their tech...  Negative
#
#              Source            Date/Time            User ID       Location  \
# 0           Twitter  2023-06-15 09:23:14            user123       New York
# ...

# %%
df['User ID'].unique()
# Out:
# array(['user123', 'user456', 'moviefan789', 'forumuser1', 'foodie22',
#        'shopper123', 'musiclover456', 'testimonialuser1', 'bookworm789',
#        'shopper789', 'travelenthusiast1', 'foodlover123', 'musiclover789',
#        'user789', 'thrillseeker1', 'buyer123', 'musicfan456', 'user1234',
#        'cinephile789', 'shopper456', 'booklover123', 'buyer789',
#        'traveler456', 'traveladdict1', 'foodie789', 'gymrat123',
#        'user987', 'thrillseeker2', 'customer123', 'musiclover987',
#        'user7890', 'foodie123', 'shopper246', 'bookworm567',
#        'shopper7890', 'user9876', 'musiclover7890', 'foodcritic123',
#        'playlistlover456', 'user24680', 'thrillseeker789', 'buyer7890',
#        'musicfan567', 'user123456', 'foodie246', 'moviegoer789',
#        'gamer123', 'traveler246', 'bookworm246', 'audiophile789',
#        'testimonialuser2', 'shopper4567', 'musiclover1234', 'user98765',
#        'traveler789', 'foodlover2468', 'nostalgiacat123', 'user12345',
# ...

# %%
df[df['User ID'] == '@user123']
# Out:
# Empty DataFrame
# Columns: [Text, Sentiment, Source, Date/Time, User ID, Location, Confidence Score]
# Index: []

# %%
df[df['User ID'] == 'user123']
# Out:
#                                    Text Sentiment   Source  \
# 0                  I love this product!  Positive  Twitter
# 8  I loved the movie! It was fantastic!  Positive     IMDb
#
#              Date/Time  User ID  Location Confidence Score
# 0  2023-06-15 09:23:14  user123  New York             0.85
# 8  2023-07-02 09:12:34  user123  New York             0.92

# %%
df.dtypes
# Out:
# Text                object
# Sentiment           object
# Source              object
# Date/Time           object
# User ID             object
# Location            object
# Confidence Score    object
# dtype: object

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %%
df.dtypes
# Out:
# Text                        object
# Sentiment                   object
# Source                      object
# Date/Time           datetime64[ns]
# User ID                     object
# Location                    object
# Confidence Score            object
# dtype: object

# %%
df['Confidence Score'] = df['Confidence Score'].astype(dtype='double')

# %%
df.dtypes
# Out:
# Text                        object
# Sentiment                   object
# Source                      object
# Date/Time           datetime64[ns]
# User ID                     object
# Location                    object
# Confidence Score           float64
# dtype: object
